# %% [markdown]
# List

# %%
list1=[1,'Jaber',12.55,True]
print(list1)
# Out:
# [1, 'Jaber', 12.55, True]

# %% [markdown]
# Creating Lists

# %%
list1=[1,2,3,4,5]

# %% [markdown]
# Create a list with 6 integers and then add all the integers at even index and print the summation.
# list1=[1,2,4,6,6,10]
# Output= Summation: 11

# %% [markdown]
# Accessing List Elements

# %%
list1=[3,4,6,7,8,9,10,33]
print(list1[5])
print(list1[-1])
print(list1[len(list1)-1])
#CSE110
# Out:
# 9
# 33
# 33

# %% [markdown]
# You have a list containing 6 numbers. Your job is to find the summation of all the numbers resides at even index of the list and then substract all the odd indexed number and print the output.
# For example,
# if the list is= [2,5,6,7,9,8]
# The out will be= 2+6+9-5-7-8=-3

# %%
list1= [2,5,6,7,9,8]
sum=0
for index in range(0,len(list1),2):
  sum=sum+list1[index]
print(sum)
# Out:
# 17

# %%
list1= [2,5,6,7,9,8]
sum=0
for index in list1:
  print(index)
  sum=sum+index
print(sum)
# Out:
# 2
# 5
# 6
# 7
# 9
# 8
# 37

# %%
list1= [2,5,6,7,9,8]
sum=0
for index in range(len(list1)):
  if (index%2==0):
    sum=sum+list1[index]
print(sum)
# Out:
# 17

# %%
list1= [2,5,6,7,9,8]
sum=0
counter=0
while counter<len(list1):
  if(counter%2==0):
    sum=sum+list1[counter]
  counter+=1
print(sum)
# Out:
# 17

# %%
list1= [2,5,6,7,9,8]
sum=0
counter=0
while counter<len(list1):
  sum=sum+list1[counter]
  counter+=2
print(sum)
# Out:
# 17

# %%
list1= [2,5,6,7,9,8]
sum=0
for index in range(0,len(list1),2):
  sum=sum+list1[index]
for index in range(1,len(list1),2):
  sum=sum-list1[index]
print(sum)
# Out:
# -3

# %%
list1= [2,5,6,7,9,8]
sum=0
for index in range(len(list1)):
  if (index%2==0):
    sum=sum+list1[index]
  else:
    sum=sum-list1[index]
print(sum)
# Out:
# -3

# %%
list1= [2,5,6,7,9,8,22]
sum=0
for index in range(0,len(list1),2):
  sum=sum+list1[index]
  if (index+1!=len(list1)):
   sum=sum-list1[index+1]
print(sum)
# Out:
# 19

# %%
list1= [2,5,6,7,9,8]
sum=0
counter=0
while counter<len(list1):
  if(counter%2==0):
    sum=sum+list1[counter]
  else:
    sum=sum-list1[counter]
  counter+=1
print(sum)
# Out:
# -3

# %% [markdown]
# **Homework:**
#
# Take two lists with 5 numbers.
# 1. Add all the even numbers from both the lists
# 2. Multiply all the odd numbers from both the lists
# 3. Add all the even indexed numbers from list1 wiht odd indexed numbers from list2
# list1=[1,2,3,4]
# list2=[4,5,9,8]
# 1. 18
# 2. 135
# 3. 17

# %% [markdown]
# List Mutability

# %%
list1=[1,2,3,4,7,8,7,88,100]
list1[4]=5
print(list1)
# Out:
# [1, 2, 3, 4, 5, 8, 7, 88, 100]

# %% [markdown]
# Adding Elements

# %%
#append()
list1=[1,2,3,4,7,8,7,88,100]
list1.append('CSE110')
print(list1)
# Out:
# [1, 2, 3, 4, 7, 8, 7, 88, 100, 'CSE110']

# %%
#extend(list)
list1=[1,2,3,4,7,8,7,88,100]
list1.extend([200,300,400])
print(list1)
# Out:
# [1, 2, 3, 4, 7, 8, 7, 88, 100, 200, 300, 400]

# %%
#insert(location[index],elemet)
list1=[1,2,3,4,7,8,7,88,100]
list1.insert(5,9)
print(list1)
# Out:
# [1, 2, 3, 4, 7, 9, 8, 7, 88, 100]

# %% [markdown]
# Deleting Elements

# %%
#pop()
#pop(index)
list1=[1,2,3,4,7,8,7,88,100]
list1.pop()
print(list1)
list1.pop(-1)
print(list1)
# Out:
# [1, 2, 3, 4, 7, 8, 7, 88]
# [1, 2, 3, 4, 7, 8, 7]

# %%
#remove(elem/value)
list1=[1,2,3,4,7,8,7,88,100]
list1.remove(8)
print(list1)
# Out:
# [1, 2, 3, 4, 7, 7, 88, 100]

# %%
#clear()
list1=[1,2,3,4,7,8,7,88,100]
list1.clear()
print(list1)
# Out:
# []

# %%
#del
list1=[1,2,3,4,7,8,7,88,100]
del list1[7]
print(list1)
del list1
print(list1)
# Out:
# [1, 2, 3, 4, 7, 8, 7, 100]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9744d6c32ba0> in <module>()
#       4 print(list1)
#       5 del list1
# ----> 6 print(list1)
#
# NameError: name 'list1' is not defined

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# More functions of list

# %%
#count(element)
list1=[1,2,3,4,7,8,7,88,100]
print(list1.count(7))
# Out:
# 2

# %%
#sort()
list1=[1,2,3,4,7,8,7,88,100]
list1.sort()
print(list1)
# Out:
# [1, 2, 3, 4, 7, 7, 8, 88, 100]

# %%
#sort()
list1=[1,2,3,4.3,7,8,7.4,88,100]
list1.sort(reverse=True)
print(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c1cbb6a1513c> in <module>()
#       1 #sort()
#       2 list1=[1,2,3,4.3,7,8,7.4,88,100,'CSE']
# ----> 3 list1.sort(reverse=True)
#       4 print(list1)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
#sort()
list1=['good','glad','cse110','jii']
list1.sort()
print(list1)
# Out:
# ['cse110', 'glad', 'good', 'jii']

# %%
#reverse
list1=[1,2,3,4.3,7,8,7.4,88,100]
list1.reverse()
print(list1)
# Out:
# [100, 88, 7.4, 8, 7, 4.3, 3, 2, 1]

# %% [markdown]
# **Homework 1:**
#
# Suppose you have a string. Your job is to find if the particular string has any "E" or 'e' in it. if the string has these character then print the index numbers that contain these character.
# Example:
# Sample input: 'Bleh Bleh Bleck shEEp'
# Sample output: [2,7,12,17,18]

# %%
#index(elem,[start,end])
list1=[1,2,3,4.3,7,8,7,88,100]
val=list1.index(7,5,len(list1))
print(val)
# Out:
# 6

# %% [markdown]
# list1=[1,2,4,6,6,10,6,3,4,5,67,10]
# find the index of 67 without using any built in function

# %%
list1=[1,2,4,6,6,10,6,3,4,5,67,10]
val=0
for index in range(len(list1)):
  if list1[index]==67:
    val=index
    break
print(val)
# Out:
# 10

# %% [markdown]
# Basic List Operations

# %%
#+
list1=[1,2,4,6,6,10,6,3,4,5,67,10]
list2=[2,3,4]
print(list1+list2)
# Out:
# [1, 2, 4, 6, 6, 10, 6, 3, 4, 5, 67, 10, 2, 3, 4]

# %%
list2=[2,3,4]
print(list2*4)
# Out:
# [2, 3, 4, 2, 3, 4, 2, 3, 4, 2, 3, 4]

# %%
list1=[1,2,4,6,6,10,6,3,4,5,67,10]
print(67 in list1)
# Out:
# True

# %% [markdown]
# List slicing

# %% [markdown]
# **Homework 2:**
#
# Suppose you have the following list:
# list1= [2,7,12,17,18,88,58,7,89,78,74,55,33,57].
# Your job is to make two seperate lists by following the below conditions:
# * List one will have only the even indexed numbers from the original list
# * List two will have only the odd indexed numberes from the original list
#
# Next, Add new list one's first element with new list two's last element, new list one's second element with new list two's second last element and so on.
#
# Print both new lists and the list created from the new lists.
#
# The output would be:
#
# New list one:
# [2,12,18,58,89,74,33]
#
# New list two:
# [7,17,88,7,78,55,57]
#
# The final list:
# [59,67,96,65,177,91,40]

# %% [markdown]
# Some built in functions

# %%
#sum
#max
#min
list1=[1,2,4,6,6,10,6,3,4,5,67,10]
print(sum(list1))
print(max(list1))
print(min(list1))
# Out:
# 124
# 67
# 1

# %%
list1=[1,2,4,6,6,10,6,3,4,5,67,10]
max=list1[0]
min=list1[0]
for index in range (1,len(list1),1):
  if(list1[index]>max):
    max=list1[index]
  if(list1[index]<min):
    min=list1[index]
print(max)
print(min)
# Out:
# 67
# 1
